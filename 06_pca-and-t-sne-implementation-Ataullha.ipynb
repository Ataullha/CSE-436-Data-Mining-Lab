# %%
from sklearn import datasets
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA

# %%
digits = datasets.load_digits()
X = digits.data
# X
y = digits.target
# y

# %%
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X)
X_pca
# Out:
# array([[ -1.25946732,  21.27488293],
#        [  7.9576108 , -20.76870027],
#        [  6.99192394,  -9.95598507],
#        ...,
#        [ 10.80128298,  -6.96025154],
#        [ -4.87209897,  12.42395248],
#        [ -0.34438928,   6.36555064]])

# %%
# X_pca[:,1]

# %%
plt.scatter(X_pca[:,0],X_pca[:,1],c=y, cmap='jet',edgecolors='k')
plt.colorbar()
plt.title("PCA Visualization")
plt.show()

# %%
from sklearn.manifold import TSNE

# %%
tsne = TSNE(n_components=2,perplexity=30, n_iter=700)

# %%
X_tsne = tsne.fit_transform(X)

# %%
X_tsne
# Out:
# array([[ -2.5971892,  43.7985   ],
#        [  9.488951 ,  -9.831123 ],
#        [-12.576819 , -17.143131 ],
#        ...,
#        [ -5.0946937,  -9.66887  ],
#        [-19.060614 ,  13.88354  ],
#        [-13.004628 ,  -6.2711525]], dtype=float32)

# %%
plt.scatter(X_tsne[:,0],X_tsne[:,1],c=y, cmap='jet', edgecolors='k')
plt.colorbar()
plt.title("TSNE Visualization")
plt.show()

# %%
100
# Out:
# 100
